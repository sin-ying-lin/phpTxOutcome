# %% [markdown]
# # Venn Diagram for RDQ Domains
# Examine oerlaps in clinically significant changes across the RDQ domains, namly the depressive symptom, non-depressive symptom, positive mental health, functioning, and well-being

# %%
library('VennDiagram')
library('dplyr')
library('gplots')
# Out:
# Loading required package: grid
#
# Loading required package: futile.logger
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df = read.csv('../Data/dfMDDMDDAll_satisfaction_rdq_dx_demo.csv')

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, non-depressive symptoms, and coping skills

# %%
venn(x[,1:3])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, non-depressive symptoms, and positive mental health

# %%
venn(x[,c(1:2,4)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, non-depressive symptoms, and functioning

# %%
venn(x[,c(1:2,5)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, non-depressive symptoms, and well-being

# %%
venn(x[,c(1:2,6)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, positive mental health, and coping skills

# %%
venn(x[,c(1,3,4)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, coping skills, and functioning

# %%
venn(x[,c(1,3,5)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, coping skills, and well-being

# %%
venn(x[,c(1,3,6)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, positive mental health, and functionoing

# %%
venn(x[,c(1,4,5)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, positive mental health, and well-being

# %%
venn(x[,c(1,4,6)])
# Out:
# plot without title

# %% [markdown]
# ## Clinically significant improvements in depressive symptoms, non-depressive symptoms, positive mental health, functionoing, and well-being

# %%
venn(x[,c(1,3:6)])
# Out:
# plot without title
